# %% [markdown]
# <img src="https://cdn.comet.ml/img/notebook_logo.png">  <img height=40px align="right" src="https://raw.githubusercontent.com/pycaret/pycaret/master/docs/images/logo.png">
#
# [Comet](https://www.comet.com/?utm_source=pycaret&utm_medium=partner&utm_campaign=partner_pycaret_2023&utm_content=comet_colab) helps accelerate machine learning through experiment tracking and production monitoring. Never lose track of your work and easily share results and collaborate across teams of all sizes. Comet is free for individual users!

# %% [markdown]
# #Install Required Packages

# %%
pip install --pre pycaret comet_ml numpy>=1.20 --quiet
# Out:
#   WARNING: Requested plotly-resampler>=0.7.2.2 from https://files.pythonhosted.org/packages/d7/5e/71a9e34a36c1855d0c4e30a88405d58c4bbbe7ece802b188628a643f2cda/plotly_resampler-0.8.4rc1.tar.gz#sha256=154ebffa9778813fe457ac9112e71e085ac283644a1e26b869bd5c6b7bf064a2 (from pycaret), but installing version 0.8.4rc1

# %% [markdown]
# #Intialize Comet
#
# Create your free account at [Comet.com](https://www.comet.com/signup?utm_source=pycaret&utm_medium=partner&utm_campaign=partner_pycaret_2023&utm_content=comet_colab) and grab your API key which can be found under your account settings

# %%
import comet_ml 

comet_ml.init(project_name="pycaret_example")
# Out:
# Please enter your Comet API key from https://www.comet.com/api/my/settings/
# (api key may not show as you type)
# Comet API key: ··········
# COMET INFO: Comet API key is valid
# COMET WARNING: running in Google Colab, but can't find mounted drive. Using HOME instead
# COMET WARNING: if drive is mounted, set COMET_CONFIG to save config there
# COMET INFO: Comet API key saved in /root/.comet.config

# %% [markdown]
# #Train and Compare Models with PyCaret

# %%
# load dataset
from pycaret.datasets import get_data
data = get_data('diabetes')

# init setup
from pycaret.classification import *
clf1 = setup(data, target = 'Class variable', log_experiment = 'comet_ml', experiment_name = 'pycaret_example', log_data=True),

# model training
best_model = compare_models()
# Out:
#    Number of times pregnant  \
# 0                         6
# 1                         1
# 2                         8
# 3                         1
# 4                         0
#
#    Plasma glucose concentration a 2 hours in an oral glucose tolerance test  \
# 0                                                148
# 1                                                 85
# 2                                                183
# 3                                                 89
# 4                                                137
#
#    Diastolic blood pressure (mm Hg)  Triceps skin fold thickness (mm)  \
# 0                                72                                35
# 1                                66                                29
# 2                                64                                 0
# 3                                66                                23
# 4                                40                                35
#
#    2-Hour serum insulin (mu U/ml)  \
# 0                               0
# 1                               0
# 2                               0
# 3                              94
# 4                             168
#
#    Body mass index (weight in kg/(height in m)^2)  Diabetes pedigree function  \
# 0                                            33.6                       0.627
# 1                                            26.6                       0.351
# 2                                            23.3                       0.672
# 3                                            28.1                       0.167
# 4                                            43.1                       2.288
#
#    Age (years)  Class variable
# 0           50               1
# 1           31               0
# 2           32               1
# 3           21               0
# 4           33               1
# <style type="text/css">
# #T_237ae_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_237ae_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Description</th>
#       <th class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_237ae_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_237ae_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_237ae_row0_col1" class="data row0 col1" >7650</td>
#     </tr>
#     <tr>
#       <th id="T_237ae_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_237ae_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_237ae_row1_col1" class="data row1 col1" >Class variable</td>
#     </tr>
#     <tr>
#       <th id="T_237ae_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_237ae_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_237ae_row2_col1" class="data row2 col1" >Binary</td>
#     </tr>
#     <tr>
#       <th id="T_237ae_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_237ae_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_237ae_row3_col1" class="data row3 col1" >(768, 9)</td>
#     </tr>
#     <tr>
#       <th id="T_237ae_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_237ae_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_237ae_row4_col1" class="data row4 col1" >(768, 9)</td>
#     </tr>
#     <tr>
#       <th id="T_237ae_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_237ae_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_237ae_row5_col1" class="data row5 col1" >(537, 9)</td>
#     </tr>
#     <tr>
#       <th id="T_237ae_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_237ae_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_237ae_row6_col1" class="data row6 col1" >(231, 9)</td>
#     </tr>
#     <tr>
#       <th id="T_237ae_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_237ae_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_237ae_row7_col1" class="data row7 col1" >8</td>
#     </tr>
#     <tr>
#       <th id="T_237ae_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_237ae_row8_col0" class="data row8 col0" >Preprocess</td>
#       <td id="T_237ae_row8_col1" class="data row8 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_237ae_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_237ae_row9_col0" class="data row9 col0" >Imputation type</td>
#       <td id="T_237ae_row9_col1" class="data row9 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_237ae_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_237ae_row10_col0" class="data row10 col0" >Numeric imputation</td>
#       <td id="T_237ae_row10_col1" class="data row10 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_237ae_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_237ae_row11_col0" class="data row11 col0" >Categorical imputation</td>
#       <td id="T_237ae_row11_col1" class="data row11 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_237ae_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_237ae_row12_col0" class="data row12 col0" >Fold Generator</td>
#       <td id="T_237ae_row12_col1" class="data row12 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_237ae_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_237ae_row13_col0" class="data row13 col0" >Fold Number</td>
#       <td id="T_237ae_row13_col1" class="data row13 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_237ae_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_237ae_row14_col0" class="data row14 col0" >CPU Jobs</td>
#       <td id="T_237ae_row14_col1" class="data row14 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_237ae_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_237ae_row15_col0" class="data row15 col0" >Use GPU</td>
#       <td id="T_237ae_row15_col1" class="data row15 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_237ae_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_237ae_row16_col0" class="data row16 col0" >Log Experiment</td>
#       <td id="T_237ae_row16_col1" class="data row16 col1" >CometLogger</td>
#     </tr>
#     <tr>
#       <th id="T_237ae_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_237ae_row17_col0" class="data row17 col0" >Experiment Name</td>
#       <td id="T_237ae_row17_col1" class="data row17 col1" >pycaret_example</td>
#     </tr>
#     <tr>
#       <th id="T_237ae_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_237ae_row18_col0" class="data row18 col0" >USI</td>
#       <td id="T_237ae_row18_col1" class="data row18 col1" >17d2</td>
#     </tr>
#   </tbody>
# </table>
# COMET WARNING: As you are running in a Jupyter environment, you will need to call `experiment.end()` when finished to ensure all metrics and code are logged before exiting.
# COMET ERROR: Failed to calculate active processors count. Fall back to default CPU count 1
# COMET INFO: Experiment is live on comet.com https://www.comet.com/sherpan/pycaret-example/bf0500021aa24b74ad2de122b1597468
#
# COMET INFO: Couldn't find a Git repository in '/content' nor in any parent directory. You can override where Comet is looking for a Git Patch by setting the configuration `COMET_GIT_DIRECTORY`
# <style type="text/css">
# #T_2b5ce_ th {
#   text-align: left;
# }
# #T_2b5ce_row0_col0, #T_2b5ce_row0_col2, #T_2b5ce_row0_col3, #T_2b5ce_row0_col4, #T_2b5ce_row0_col5, #T_2b5ce_row0_col6, #T_2b5ce_row0_col7, #T_2b5ce_row1_col0, #T_2b5ce_row1_col1, #T_2b5ce_row1_col3, #T_2b5ce_row1_col4, #T_2b5ce_row2_col0, #T_2b5ce_row2_col1, #T_2b5ce_row2_col2, #T_2b5ce_row2_col3, #T_2b5ce_row2_col5, #T_2b5ce_row2_col6, #T_2b5ce_row2_col7, #T_2b5ce_row3_col0, #T_2b5ce_row3_col1, #T_2b5ce_row3_col2, #T_2b5ce_row3_col3, #T_2b5ce_row3_col4, #T_2b5ce_row3_col5, #T_2b5ce_row3_col6, #T_2b5ce_row3_col7, #T_2b5ce_row4_col0, #T_2b5ce_row4_col1, #T_2b5ce_row4_col2, #T_2b5ce_row4_col3, #T_2b5ce_row4_col4, #T_2b5ce_row4_col5, #T_2b5ce_row4_col6, #T_2b5ce_row4_col7, #T_2b5ce_row5_col0, #T_2b5ce_row5_col1, #T_2b5ce_row5_col2, #T_2b5ce_row5_col3, #T_2b5ce_row5_col4, #T_2b5ce_row5_col5, #T_2b5ce_row5_col6, #T_2b5ce_row5_col7, #T_2b5ce_row6_col0, #T_2b5ce_row6_col1, #T_2b5ce_row6_col2, #T_2b5ce_row6_col4, #T_2b5ce_row6_col5, #T_2b5ce_row6_col6, #T_2b5ce_row6_col7, #T_2b5ce_row7_col0, #T_2b5ce_row7_col1, #T_2b5ce_row7_col2, #T_2b5ce_row7_col3, #T_2b5ce_row7_col4, #T_2b5ce_row7_col5, #T_2b5ce_row7_col6, #T_2b5ce_row7_col7, #T_2b5ce_row8_col0, #T_2b5ce_row8_col1, #T_2b5ce_row8_col2, #T_2b5ce_row8_col3, #T_2b5ce_row8_col4, #T_2b5ce_row8_col5, #T_2b5ce_row8_col6, #T_2b5ce_row8_col7, #T_2b5ce_row9_col0, #T_2b5ce_row9_col1, #T_2b5ce_row9_col2, #T_2b5ce_row9_col3, #T_2b5ce_row9_col4, #T_2b5ce_row9_col5, #T_2b5ce_row9_col6, #T_2b5ce_row9_col7, #T_2b5ce_row10_col0, #T_2b5ce_row10_col1, #T_2b5ce_row10_col2, #T_2b5ce_row10_col3, #T_2b5ce_row10_col4, #T_2b5ce_row10_col5, #T_2b5ce_row10_col6, #T_2b5ce_row10_col7, #T_2b5ce_row11_col0, #T_2b5ce_row11_col1, #T_2b5ce_row11_col2, #T_2b5ce_row11_col3, #T_2b5ce_row11_col4, #T_2b5ce_row11_col5, #T_2b5ce_row11_col6, #T_2b5ce_row11_col7, #T_2b5ce_row12_col0, #T_2b5ce_row12_col1, #T_2b5ce_row12_col2, #T_2b5ce_row12_col3, #T_2b5ce_row12_col4, #T_2b5ce_row12_col5, #T_2b5ce_row12_col6, #T_2b5ce_row12_col7, #T_2b5ce_row13_col0, #T_2b5ce_row13_col1, #T_2b5ce_row13_col2, #T_2b5ce_row13_col3, #T_2b5ce_row13_col4, #T_2b5ce_row13_col5, #T_2b5ce_row13_col6, #T_2b5ce_row13_col7, #T_2b5ce_row14_col0, #T_2b5ce_row14_col1, #T_2b5ce_row14_col2, #T_2b5ce_row14_col3, #T_2b5ce_row14_col4, #T_2b5ce_row14_col5, #T_2b5ce_row14_col6, #T_2b5ce_row14_col7 {
#   text-align: left;
# }
# #T_2b5ce_row0_col1, #T_2b5ce_row1_col2, #T_2b5ce_row1_col5, #T_2b5ce_row1_col6, #T_2b5ce_row1_col7, #T_2b5ce_row2_col4, #T_2b5ce_row6_col3 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_2b5ce_row0_col8, #T_2b5ce_row1_col8, #T_2b5ce_row2_col8, #T_2b5ce_row3_col8, #T_2b5ce_row4_col8, #T_2b5ce_row5_col8, #T_2b5ce_row6_col8, #T_2b5ce_row7_col8, #T_2b5ce_row8_col8, #T_2b5ce_row9_col8, #T_2b5ce_row10_col8, #T_2b5ce_row11_col8, #T_2b5ce_row12_col8, #T_2b5ce_row14_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_2b5ce_row13_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_2b5ce_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Model</th>
#       <th class="col_heading level0 col1" >Accuracy</th>
#       <th class="col_heading level0 col2" >AUC</th>
#       <th class="col_heading level0 col3" >Recall</th>
#       <th class="col_heading level0 col4" >Prec.</th>
#       <th class="col_heading level0 col5" >F1</th>
#       <th class="col_heading level0 col6" >Kappa</th>
#       <th class="col_heading level0 col7" >MCC</th>
#       <th class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2b5ce_level0_row0" class="row_heading level0 row0" >et</th>
#       <td id="T_2b5ce_row0_col0" class="data row0 col0" >Extra Trees Classifier</td>
#       <td id="T_2b5ce_row0_col1" class="data row0 col1" >0.7653</td>
#       <td id="T_2b5ce_row0_col2" class="data row0 col2" >0.8242</td>
#       <td id="T_2b5ce_row0_col3" class="data row0 col3" >0.5561</td>
#       <td id="T_2b5ce_row0_col4" class="data row0 col4" >0.7096</td>
#       <td id="T_2b5ce_row0_col5" class="data row0 col5" >0.6208</td>
#       <td id="T_2b5ce_row0_col6" class="data row0 col6" >0.4550</td>
#       <td id="T_2b5ce_row0_col7" class="data row0 col7" >0.4640</td>
#       <td id="T_2b5ce_row0_col8" class="data row0 col8" >0.3210</td>
#     </tr>
#     <tr>
#       <th id="T_2b5ce_level0_row1" class="row_heading level0 row1" >gbc</th>
#       <td id="T_2b5ce_row1_col0" class="data row1 col0" >Gradient Boosting Classifier</td>
#       <td id="T_2b5ce_row1_col1" class="data row1 col1" >0.7635</td>
#       <td id="T_2b5ce_row1_col2" class="data row1 col2" >0.8282</td>
#       <td id="T_2b5ce_row1_col3" class="data row1 col3" >0.6158</td>
#       <td id="T_2b5ce_row1_col4" class="data row1 col4" >0.6840</td>
#       <td id="T_2b5ce_row1_col5" class="data row1 col5" >0.6444</td>
#       <td id="T_2b5ce_row1_col6" class="data row1 col6" >0.4687</td>
#       <td id="T_2b5ce_row1_col7" class="data row1 col7" >0.4731</td>
#       <td id="T_2b5ce_row1_col8" class="data row1 col8" >0.3510</td>
#     </tr>
#     <tr>
#       <th id="T_2b5ce_level0_row2" class="row_heading level0 row2" >ridge</th>
#       <td id="T_2b5ce_row2_col0" class="data row2 col0" >Ridge Classifier</td>
#       <td id="T_2b5ce_row2_col1" class="data row2 col1" >0.7616</td>
#       <td id="T_2b5ce_row2_col2" class="data row2 col2" >0.0000</td>
#       <td id="T_2b5ce_row2_col3" class="data row2 col3" >0.5404</td>
#       <td id="T_2b5ce_row2_col4" class="data row2 col4" >0.7154</td>
#       <td id="T_2b5ce_row2_col5" class="data row2 col5" >0.6096</td>
#       <td id="T_2b5ce_row2_col6" class="data row2 col6" >0.4439</td>
#       <td id="T_2b5ce_row2_col7" class="data row2 col7" >0.4569</td>
#       <td id="T_2b5ce_row2_col8" class="data row2 col8" >0.1110</td>
#     </tr>
#     <tr>
#       <th id="T_2b5ce_level0_row3" class="row_heading level0 row3" >lr</th>
#       <td id="T_2b5ce_row3_col0" class="data row3 col0" >Logistic Regression</td>
#       <td id="T_2b5ce_row3_col1" class="data row3 col1" >0.7597</td>
#       <td id="T_2b5ce_row3_col2" class="data row3 col2" >0.8069</td>
#       <td id="T_2b5ce_row3_col3" class="data row3 col3" >0.5512</td>
#       <td id="T_2b5ce_row3_col4" class="data row3 col4" >0.7029</td>
#       <td id="T_2b5ce_row3_col5" class="data row3 col5" >0.6121</td>
#       <td id="T_2b5ce_row3_col6" class="data row3 col6" >0.4431</td>
#       <td id="T_2b5ce_row3_col7" class="data row3 col7" >0.4537</td>
#       <td id="T_2b5ce_row3_col8" class="data row3 col8" >0.3400</td>
#     </tr>
#     <tr>
#       <th id="T_2b5ce_level0_row4" class="row_heading level0 row4" >lda</th>
#       <td id="T_2b5ce_row4_col0" class="data row4 col0" >Linear Discriminant Analysis</td>
#       <td id="T_2b5ce_row4_col1" class="data row4 col1" >0.7597</td>
#       <td id="T_2b5ce_row4_col2" class="data row4 col2" >0.8062</td>
#       <td id="T_2b5ce_row4_col3" class="data row4 col3" >0.5512</td>
#       <td id="T_2b5ce_row4_col4" class="data row4 col4" >0.7008</td>
#       <td id="T_2b5ce_row4_col5" class="data row4 col5" >0.6119</td>
#       <td id="T_2b5ce_row4_col6" class="data row4 col6" >0.4428</td>
#       <td id="T_2b5ce_row4_col7" class="data row4 col7" >0.4527</td>
#       <td id="T_2b5ce_row4_col8" class="data row4 col8" >0.0500</td>
#     </tr>
#     <tr>
#       <th id="T_2b5ce_level0_row5" class="row_heading level0 row5" >rf</th>
#       <td id="T_2b5ce_row5_col0" class="data row5 col0" >Random Forest Classifier</td>
#       <td id="T_2b5ce_row5_col1" class="data row5 col1" >0.7560</td>
#       <td id="T_2b5ce_row5_col2" class="data row5 col2" >0.8197</td>
#       <td id="T_2b5ce_row5_col3" class="data row5 col3" >0.5564</td>
#       <td id="T_2b5ce_row5_col4" class="data row5 col4" >0.6859</td>
#       <td id="T_2b5ce_row5_col5" class="data row5 col5" >0.6124</td>
#       <td id="T_2b5ce_row5_col6" class="data row5 col6" >0.4377</td>
#       <td id="T_2b5ce_row5_col7" class="data row5 col7" >0.4442</td>
#       <td id="T_2b5ce_row5_col8"
# Processing:   0%|          | 0/65 [00:00<?, ?it/s]
# COMET WARNING: Cannot safely convert           runtime                         Object  \
# et           3.47           ExtraTreesClassifier
# gbc          3.78     GradientBoostingClassifier
# ridge        1.62                RidgeClassifier
# lr           3.77             LogisticRegression
# lda          0.78     LinearDiscriminantAnalysis
# rf           6.28         RandomForestClassifier
# xgboost      2.06                  XGBClassifier
# lightgbm     1.62                 LGBMClassifier
# nb           1.23                     GaussianNB
# ada          3.09             AdaBoostClassifier
# qda          1.29  QuadraticDiscriminantAnalysis
# knn          1.44           KNeighborsClassifier
# dt           2.32         DecisionTreeClassifier
# dummy        0.73                DummyClassifier
# svm          1.92                  SGDClassifier
#
#                                     Model  Accuracy     AUC  Recall   Prec.  \
# et                 Extra Trees Classifier    0.7653  0.8242  0.5561  0.7096
# gbc          Gradient Boosting Classifier    0.7635  0.8282  0.6158  0.6840
# ridge                    Ridge Classifier    0.7616  0.0000  0.5404  0.7154
# lr                    Logistic Regression    0.7597  0.8069  0.5512  0.7029
# lda          Linear Discriminant Analysis    0.7597  0.8062  0.5512  0.7008
# rf               Random Forest Classifier    0.7560  0.8197  0.5564  0.6859
# xgboost         Extreme Gradient Boosting    0.7391  0.7912  0.6199  0.6278
# lightgbm  Light Gradient Boosting Machine    0.7318  0.7943  0.5830  0.6237
# nb                            Naive Bayes    0.7206  0.7897  0.5351  0.6171
# ada                  Ada Boost Classifier    0.7151  0.7669  0.4927  0.6196
# qda       Quadratic Discriminant Analysis    0.7113  0.7913  0.5129  0.6070
# knn                K Neighbors Classifier    0.7037  0.7251  0.4965  0.5921
# dt               Decision Tree Classifier    0.6835  0.6572  0.5716  0.5624
# dummy                    Dummy Classifier    0.6518  0.5000  0.0000  0.0000
# svm                   SVM - Linear Kernel    0.5977  0.0000  0.3690  0.4052
#
#               F1   Kappa     MCC  TT (Sec)
# et        0.6208  0.4550  0.4640     0.321
# gbc       0.6444  0.4687  0.4731     0.351
# ridge     0.6096  0.4439  0.4569     0.111
# lr        0.6121  0.4431  0.4537     0.340
# lda       0.6119  0.4428  0.4527     0.050
# rf        0.6124  0.4377  0.4442     0.575
# xgboost   0.6210  0.4228  0.4250     0.179
# lightgbm  0.5984  0.3986  0.4022     0.136
# nb        0.5691  0.3652  0.3696     0.088
# ada       0.5440  0.3421  0.3498     0.268
# qda       0.5530  0.3423  0.3471     0.085
# knn       0.5381  0.3229  0.3269     0.106
# dt        0.5601  0.3151  0.3195     0.160
# dummy     0.0000  0.0000  0.0000     0.046
# svm       0.3413  0.0923  0.1042     0.121   object to a scalar value, using its string representation for logging. Resulting string might be invalid
# COMET WARNING: truncated string; too long: '          runtime                         Object  \
# et           3.47           ExtraTreesClassifier
# gbc          3.78     GradientBoostingClassifier
# ridge        1.62                RidgeClassifier
# lr           3.77             LogisticRegression
# lda          0.78     LinearDiscriminantAnalysis
# rf           6.28         RandomForestClassifier
# xgboost      2.06                  XGBClassifier
# lightgbm     1.62                 LGBMClassifier
# nb           1.23                     GaussianNB
# ada          3.09             AdaBoostClassifier
# qda          1.29  QuadraticDiscriminantAnalysis
# knn          1.44           KNeighborsClassifier
# dt           2.32         DecisionTreeClassifier
# dummy        0.73                DummyClassifier
# svm          1.92                  SGDClassifier
#
#                                     Model  Accuracy     AUC  Recall   Prec.  \
# et                 Extra Trees Classifier    0.7653  0.8242  0.5561  0.7096
# gbc          Gradient Boosting Classifier    0.7635  0.8282  0.6158  0.6840
# ridge                    Ridge Classifier    0.7616  0.0000  0.5404  0.7154
# lr                    Logistic Regression    0.7597  0.8069  0.5512  0.7029
# lda          Linear Discriminant Analysis    0.7597  0.8062  0.5512  0.7008
# rf               Random Forest Classifier    0.7560  0.8197  0.5564  0.6859
# xgboost         Extreme Gradient Boosting    0.7391  0.7912  0.6199  0.6278
# lightgbm  Light Gradient Boosting Machine    0.7318  0.7943  0.5830  0.6237
# nb                            Naive Bayes    0.7206  0.7897  0.5351  0.6171
# ada                  Ada Boost Classifier    0.7151  0.7669  0.4927  0.6196
# qda       Quadratic Discriminant Analysis    0.7113  0.7913  0.5129  0.6070
# knn                K Neighbors Classifier    0.7037  0.7251  0.4965  0.5921
# dt               Decision Tree Classifier    0.6835  0.6572  0.5716  0.5624
# dummy                    Dummy Classifier    0.6518  0.5000  0.0000  0.0000
# svm                   SVM - Linear Kernel    0.5977  0.0000  0.3690  0.4052
#
#               F1   Kappa     MCC  TT (Sec)
# et        0.6208  0.4550  0.4640     0.321
# gbc       0.6444  0.4687  0.4731     0.351
# ridge     0.6096  0.4439  0.4569     0.111
# lr        0.6121  0.4431  0.4537     0.340
# lda       0.6119  0.4428  0.4527     0.050
# rf        0.6124  0.4377  0.4442     0.575
# xgboost   0.6210  0.4228  0.4250     0.179
# lightgbm  0.5984  0.3986  0.4022     0.136
# nb        0.5691  0.3652  0.3696     0.088
# ada       0.5440  0.3421  0.3498     0.268
# qda       0.5530  0.3423  0.3471     0.085
# knn       0.5381  0.3229  0.3269     0.106
# dt        0.5601  0.3151  0.3195     0.160
# dummy     0.0000  0.0000  0.0000     0.046
# svm       0.3413  0.0923  0.1042     0.121  '...
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO: Comet.ml Experiment Summary
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO:   Data:
# COMET INFO:     display_summary_level : 1
# COMET INFO:     url                   : https://www.comet.com/sherpan/pycaret-example/bf0500021aa24b74ad2de122b1597468
# COMET INFO:   Metrics:
# COMET INFO:     compare_models :           runtime                         Object  \
# et           3.47           ExtraTreesClassifier
# gbc          3.78     GradientBoostingClassifier
# ridge        1.62                RidgeClassifier
# lr           3.77             LogisticRegression
# lda          0.78     LinearDiscriminantAnalysis
# rf           6.28         RandomForestClassifier
# xgboost      2.06                  XGBClassifier
# lightgbm     1.62                 LGBMClassifier
# nb           1.23                     GaussianNB
# ada          3.09             AdaBoostClassifier
# qda          1.29  QuadraticDiscriminantAnalysis
# knn          1.44           KNeighborsClassifier
# dt           2.32         DecisionTreeClassifier
# dummy        0.73                DummyClassifier
# svm          1.92                  SGDClassifier
#
#                                     Model  Accuracy     AUC  Recall   Prec.  \
# et                 Extra Trees Classifier    0.7653  0.8242  0.5561  0.7096  [truncated]
# COMET INFO:   Others:
# COMET INFO:     Name : Session Initialized 17d2
# COMET INFO:   Parameters:
# COMET INFO:     add_indicator                     : False
# COMET INFO:     bootstrap                         : False
# COMET INFO:     ccp_alpha                         : 0.0
# COMET INFO:     class_weight                      : 1
# COMET INFO:     copy                              : True
# COMET INFO:     criterion                         : gini
# COMET INFO:     fill_value                        : 1
# COMET INFO:     max_depth                         : 1
# COMET INFO:     max_features                      : auto
# COMET INFO:     max_leaf_nodes                    : 1
# COMET INFO:     max_samples                       : 1
# COMET INFO:     min_impurity_decrease             : 0.0
# COMET INFO:     min_samples_leaf                  : 1
# COMET INFO:     min_samples_split                 : 2
# COMET INFO:     min_weight_fraction_leaf          : 0.0
# COMET INFO:     missing_values                    : nan
# COMET INFO:     n_estimators                      : 100
# COMET INFO:     n_jobs                            : -1
# COMET INFO:     oob_score                         : False
# COMET INFO:     random_state                      : 7650
# COMET INFO:     setup_CPU Jobs                    : -1
# COMET INFO:     setup_Categorical imputation      : mode
# COMET INFO:     setup_Experiment Name             : pycaret_example
# COMET INFO:     setup_Fold Generator              : StratifiedKFold
# COMET INFO:     setup_Fold Number                 : 10
# COMET INFO:     setup_Imputation type             : simple
# COMET INFO:     setup_Log Experiment              : CometLogger
# COMET INFO:     setup_Numeric features            : 8
# COMET INFO:     setup_Numeric imputation          : mean
# COMET INFO:     setup_Original data shape         : (768, 9)
# COMET INFO:     setup_Preprocess                  : True
# COMET INFO:     setup_Session id                  : 7650
# COMET INFO:     setup_Target                      : Class variable
# COMET INFO:     setup_Target type                 : Binary
# COMET INFO:     setup_Transformed data shape      : (768, 9)
# COMET INFO:     setup_Transformed test set shape  : (231, 9)
# COMET INFO:     setup_Transformed train set shape : (537, 9)
# COMET INFO:     setup_USI                         : 17d2
# COMET INFO:     setup_Use GPU                     : False
# COMET INFO:     splitter                          : random
# COMET INFO:     strategy                          : mean
# COMET INFO:     verbose                           : 0
# COMET INFO:     warm_start                        : False
# COMET INFO:   Uploads:
# COMET INFO:     asset               : 3 (31.21 KB)
# COMET INFO:     environment details : 1
# COMET INFO:     filename            : 1
# COMET INFO:     installed packages  : 1
# COMET INFO:     notebook            : 2
# COMET INFO:     os packages         : 1
# COMET INFO:     source_code         : 1
# COMET INFO:
# COMET WARNING: As you are running in a Jupyter environment, you will need to call `experiment.end()` when finished to ensure all metrics and code are logged before exiting.
# COMET ERROR: Failed to calculate active processors count. Fall back to default CPU count 1
# COMET INFO: Couldn't find a Git repository in '/content' nor in any parent directory. You can override where Comet is looking for a Git Patch by setting the configuration `COMET_GIT_DIRECTORY`
# COMET INFO: Experiment is live on comet.com https://www.comet.com/sherpan/pycaret-example/89708cf638ad4fcd99f6099c536ae2da
#
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO: Comet.ml Experiment Summary
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO:   Data:
# COMET INFO:     display_summary_level : 1
# COMET INFO:     url                   : https://www.comet.com/sherpan/pycaret-example/89708cf638ad4fcd99f6099c536ae2da
# COMET INFO:   Metrics:
# COMET INFO:     AUC      : 0.8242
# COMET INFO:     Accuracy : 0.7653
# COMET INFO:     F1       : 0.6208
# COMET INFO:     Kappa    : 0.455
# COMET INFO:     MCC      : 0.464
# COMET INFO:     Prec.    : 0.7096
# COMET INFO:     Recall   : 0.5561
# COMET INFO:     TT       : 0.321
# COMET INFO:   Others:
# COMET INFO:     Created from : pycaret
# COMET INFO:     Name         : Extra Trees Classifier
# COMET INFO:   Parameters:
# COMET INFO:     Extra Trees Classifier_bootstrap                : False
# COMET INFO:     Extra Trees Classifier_ccp_alpha                : 0.0
# COMET INFO:     Extra Trees Classifier_class_weight             : 1
# COMET INFO:     Extra Trees Classifier_criterion                : gini
# COMET INFO:     Extra Trees Classifier_max_depth                : 1
# COMET INFO:     Extra Trees Classifier_max_features             : auto
# COMET INFO:     Extra Trees Classifier_max_leaf_nodes           : 1
# COMET INFO:     Extra Trees Classifier_max_samples              : 1
# COMET INFO:     Extra Trees Classifier_min_impurity_decrease    : 0.0
# COMET INFO:     Extra Trees Classifier_min_samples_leaf         : 1
# COMET INFO:     Extra Trees Classifier_min_samples_split        : 2
# COMET INFO:     Extra Trees Classifier_min_weight_fraction_leaf : 0.0
# COMET INFO:     Extra Trees Classifier_n_estimators             : 100
# COMET INFO:     Extra Trees Classifier_n_jobs                   : -1
# COMET INFO:     Extra Trees Classifier_oob_score                : False
# COMET INFO:     Extra Trees Classifier_random_state             : 7650
# COMET INFO:     Extra Trees Classifier_verbose                  : 0
# COMET INFO:     Extra Trees Classifier_warm_start               : False
# COMET INFO:   Uploads:
# COMET INFO:     environment details : 1
# COMET INFO:     filename            : 1
# COMET INFO:     installed packages  : 1
# COMET INFO:     notebook            : 2
# COMET INFO:     os packages         : 1
# COMET INFO:     source_code         : 1
# COMET INFO:
# COMET WARNING: As you are running in a Jupyter environment, you will need to call `experiment.end()` when finished to ensure all metrics and code are logged before exiting.
# COMET ERROR: Failed to calculate active processors count. Fall back to default CPU count 1
# COMET INFO: Couldn't find a Git repository in '/content' nor in any parent directory. You can override where Comet is looking for a Git Patch by setting the configuration `COMET_GIT_DIRECTORY`
# COMET INFO: Experiment is live on comet.com https://www.comet.com/sherpan/pycaret-example/163a223e089a4661b580df8e85ea3188
#
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO: Comet.ml Experiment Summary
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO:   Data:
# COMET INFO:     display_summary_level : 1
# COMET INFO:     url                   : https://www.comet.com/sherpan/pycaret-example/163a223e089a4661b580df8e85ea3188
# COMET INFO:   Metrics:
# COMET INFO:     AUC      : 0.8282
# COMET INFO:     Accuracy : 0.7635
# COMET INFO:     F1       : 0.6444
# COMET INFO:     Kappa    : 0.4687
# COMET INFO:     MCC      : 0.4731
# COMET INFO:     Prec.    : 0.684
# COMET INFO:     Recall   : 0.6158
# COMET INFO:     TT       : 0.351
# COMET INFO:   Others:
# COMET INFO:     Created from : pycaret
# COMET INFO:     Name         : Gradient Boosting Classifier
# COMET INFO:   Parameters:
# COMET INFO:     Gradient Boosting Classifier_ccp_alpha                : 0.0
# COMET INFO:     Gradient Boosting Classifier_criterion                : friedman_mse
# COMET INFO:     Gradient Boosting Classifier_init                     : 1
# COMET INFO:     Gradient Boosting Classifier_learning_rate            : 0.1
# COMET INFO:     Gradient Boosting Classifier_loss                     : deviance
# COMET INFO:     Gradient Boosting Classifier_max_depth                : 3
# COMET INFO:     Gradient Boosting Classifier_max_features             : 1
# COMET INFO:     Gradient Boosting Classifier_max_leaf_nodes           : 1
# COMET INFO:     Gradient Boosting Classifier_min_impurity_decrease    : 0.0
# COMET INFO:     Gradient Boosting Classifier_min_samples_leaf         : 1
# COMET INFO:     Gradient Boosting Classifier_min_samples_split        : 2
# COMET INFO:     Gradient Boosting Classifier_min_weight_fraction_leaf : 0.0
# COMET INFO:     Gradient Boosting Classifier_n_estimators             : 100
# COMET INFO:     Gradient Boosting Classifier_n_iter_no_change         : 1
# COMET INFO:     Gradient Boosting Classifier_random_state             : 7650
# COMET INFO:     Gradient Boosting Classifier_subsample                : 1.0
# COMET INFO:     Gradient Boosting Classifier_tol                      : 0.0001
# COMET INFO:     Gradient Boosting Classifier_validation_fraction      : 0.1
# COMET INFO:     Gradient Boosting Classifier_verbose                  : 0
# COMET INFO:     Gradient Boosting Classifier_warm_start               : False
# COMET INFO:   Uploads:
# COMET INFO:     environment details : 1
# COMET INFO:     filename            : 1
# COMET INFO:     installed packages  : 1
# COMET INFO:     notebook            : 2
# COMET INFO:     os packages         : 1
# COMET INFO:     source_code         : 1
# COMET INFO:
# COMET WARNING: As you are running in a Jupyter environment, you will need to call `experiment.end()` when finished to ensure all metrics and code are logged before exiting.
# COMET ERROR: Failed to calculate active processors count. Fall back to default CPU count 1
# COMET INFO: Couldn't find a Git repository in '/content' nor in any parent directory. You can override where Comet is looking for a Git Patch by setting the configuration `COMET_GIT_DIRECTORY`
# COMET INFO: Experiment is live on comet.com https://www.comet.com/sherpan/pycaret-example/a77bbba3f45546d197f7334812d7aa94
#
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO: Comet.ml Experiment Summary
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO:   Data:
# COMET INFO:     display_summary_level : 1
# COMET INFO:     url                   : https://www.comet.com/sherpan/pycaret-example/a77bbba3f45546d197f7334812d7aa94
# COMET INFO:   Metrics:
# COMET INFO:     AUC      : 0.0
# COMET INFO:     Accuracy : 0.7616
# COMET INFO:     F1       : 0.6096
# COMET INFO:     Kappa    : 0.4439
# COMET INFO:     MCC      : 0.4569
# COMET INFO:     Prec.    : 0.7154
# COMET INFO:     Recall   : 0.5404
# COMET INFO:     TT       : 0.111
# COMET INFO:   Others:
# COMET INFO:     Created from : pycaret
# COMET INFO:     Name         : Ridge Classifier
# COMET INFO:   Parameters:
# COMET INFO:     Ridge Classifier_alpha         : 1.0
# COMET INFO:     Ridge Classifier_class_weight  : 1
# COMET INFO:     Ridge Classifier_copy_X        : True
# COMET INFO:     Ridge Classifier_fit_intercept : True
# COMET INFO:     Ridge Classifier_max_iter      : 1
# COMET INFO:     Ridge Classifier_normalize     : deprecated
# COMET INFO:     Ridge Classifier_positive      : False
# COMET INFO:     Ridge Classifier_random_state  : 7650
# COMET INFO:     Ridge Classifier_solver        : auto
# COMET INFO:     Ridge Classifier_tol           : 0.001
# COMET INFO:   Uploads:
# COMET INFO:     environment details : 1
# COMET INFO:     filename            : 1
# COMET INFO:     installed packages  : 1
# COMET INFO:     notebook            : 2
# COMET INFO:     os packages         : 1
# COMET INFO:     source_code         : 1
# COMET INFO:
# COMET WARNING: As you are running in a Jupyter environment, you will need to call `experiment.end()` when finished to ensure all metrics and code are logged before exiting.
# COMET ERROR: Failed to calculate active processors count. Fall back to default CPU count 1
# COMET INFO: Couldn't find a Git repository in '/content' nor in any parent directory. You can override where Comet is looking for a Git Patch by setting the configuration `COMET_GIT_DIRECTORY`
# COMET INFO: Experiment is live on comet.com https://www.comet.com/sherpan/pycaret-example/731b9c839ecb43e7b6450486e71b15cf
#
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO: Comet.ml Experiment Summary
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO:   Data:
# COMET INFO:     display_summary_level : 1
# COMET INFO:     url                   : https://www.comet.com/sherpan/pycaret-example/731b9c839ecb43e7b6450486e71b15cf
# COMET INFO:   Metrics:
# COMET INFO:     AUC      : 0.8069
# COMET INFO:     Accuracy : 0.7597
# COMET INFO:     F1       : 0.6121
# COMET INFO:     Kappa    : 0.4431
# COMET INFO:     MCC      : 0.4537
# COMET INFO:     Prec.    : 0.7029
# COMET INFO:     Recall   : 0.5512
# COMET INFO:     TT       : 0.34
# COMET INFO:   Others:
# COMET INFO:     Created from : pycaret
# COMET INFO:     Name         : Logistic Regression
# COMET INFO:   Parameters:
# COMET INFO:     Logistic Regression_C                 : 1.0
# COMET INFO:     Logistic Regression_class_weight      : 1
# COMET INFO:     Logistic Regression_dual              : False
# COMET INFO:     Logistic Regression_fit_intercept     : True
# COMET INFO:     Logistic Regression_intercept_scaling : 1
# COMET INFO:     Logistic Regression_l1_ratio          : 1
# COMET INFO:     Logistic Regression_max_iter          : 1000
# COMET INFO:     Logistic Regression_multi_class       : auto
# COMET INFO:     Logistic Regression_n_jobs            : 1
# COMET INFO:     Logistic Regression_penalty           : l2
# COMET INFO:     Logistic Regression_random_state      : 7650
# COMET INFO:     Logistic Regression_solver            : lbfgs
# COMET INFO:     Logistic Regression_tol               : 0.0001
# COMET INFO:     Logistic Regression_verbose           : 0
# COMET INFO:     Logistic Regression_warm_start        : False
# COMET INFO:   Uploads:
# COMET INFO:     environment details : 1
# COMET INFO:     filename            : 1
# COMET INFO:     installed packages  : 1
# COMET INFO:     notebook            : 2
# COMET INFO:     os packages         : 1
# COMET INFO:     source_code         : 1
# COMET INFO:
# COMET WARNING: As you are running in a Jupyter environment, you will need to call `experiment.end()` when finished to ensure all metrics and code are logged before exiting.
# COMET ERROR: Failed to calculate active processors count. Fall back to default CPU count 1
# COMET INFO: Couldn't find a Git repository in '/content' nor in any parent directory. You can override where Comet is looking for a Git Patch by setting the configuration `COMET_GIT_DIRECTORY`
# COMET INFO: Experiment is live on comet.com https://www.comet.com/sherpan/pycaret-example/9cf536bd5fb14b2dad9b1bc52a91a501
#
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO: Comet.ml Experiment Summary
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO:   Data:
# COMET INFO:     display_summary_level : 1
# COMET INFO:     url                   : https://www.comet.com/sherpan/pycaret-example/9cf536bd5fb14b2dad9b1bc52a91a501
# COMET INFO:   Metrics:
# COMET INFO:     AUC      : 0.8062
# COMET INFO:     Accuracy : 0.7597
# COMET INFO:     F1       : 0.6119
# COMET INFO:     Kappa    : 0.4428
# COMET INFO:     MCC      : 0.4527
# COMET INFO:     Prec.    : 0.7008
# COMET INFO:     Recall   : 0.5512
# COMET INFO:     TT       : 0.05
# COMET INFO:   Others:
# COMET INFO:     Created from : pycaret
# COMET INFO:     Name         : Linear Discriminant Analysis
# COMET INFO:   Parameters:
# COMET INFO:     Linear Discriminant Analysis_covariance_estimator : 1
# COMET INFO:     Linear Discriminant Analysis_n_components         : 1
# COMET INFO:     Linear Discriminant Analysis_priors               : 1
# COMET INFO:     Linear Discriminant Analysis_shrinkage            : 1
# COMET INFO:     Linear Discriminant Analysis_solver               : svd
# COMET INFO:     Linear Discriminant Analysis_store_covariance     : False
# COMET INFO:     Linear Discriminant Analysis_tol                  : 0.0001
# COMET INFO:   Uploads:
# COMET INFO:     environment details : 1
# COMET INFO:     filename            : 1
# COMET INFO:     installed packages  : 1
# COMET INFO:     notebook            : 2
# COMET INFO:     os packages         : 1
# COMET INFO:     source_code         : 1
# COMET INFO:
# COMET WARNING: As you are running in a Jupyter environment, you will need to call `experiment.end()` when finished to ensure all metrics and code are logged before exiting.
# COMET ERROR: Failed to calculate active processors count. Fall back to default CPU count 1
# COMET INFO: Couldn't find a Git repository in '/content' nor in any parent directory. You can override where Comet is looking for a Git Patch by setting the configuration `COMET_GIT_DIRECTORY`
# COMET INFO: Experiment is live on comet.com https://www.comet.com/sherpan/pycaret-example/a7195185bfe04f0abb3074e00b2d403b
#
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO: Comet.ml Experiment Summary
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO:   Data:
# COMET INFO:     display_summary_level : 1
# COMET INFO:     url                   : https://www.comet.com/sherpan/pycaret-example/a7195185bfe04f0abb3074e00b2d403b
# COMET INFO:   Metrics:
# COMET INFO:     AUC      : 0.8197
# COMET INFO:     Accuracy : 0.756
# COMET INFO:     F1       : 0.6124
# COMET INFO:     Kappa    : 0.4377
# COMET INFO:     MCC      : 0.4442
# COMET INFO:     Prec.    : 0.6859
# COMET INFO:     Recall   : 0.5564
# COMET INFO:     TT       : 0.575
# COMET INFO:   Others:
# COMET INFO:     Created from : pycaret
# COMET INFO:     Name         : Random Forest Classifier
# COMET INFO:   Parameters:
# COMET INFO:     Random Forest Classifier_bootstrap                : True
# COMET INFO:     Random Forest Classifier_ccp_alpha                : 0.0
# COMET INFO:     Random Forest Classifier_class_weight             : 1
# COMET INFO:     Random Forest Classifier_criterion                : gini
# COMET INFO:     Random Forest Classifier_max_depth                : 1
# COMET INFO:     Random Forest Classifier_max_features             : auto
# COMET INFO:     Random Forest Classifier_max_leaf_nodes           : 1
# COMET INFO:     Random Forest Classifier_max_samples              : 1
# COMET INFO:     Random Forest Classifier_min_impurity_decrease    : 0.0
# COMET INFO:     Random Forest Classifier_min_samples_leaf         : 1
# COMET INFO:     Random Forest Classifier_min_samples_split        : 2
# COMET INFO:     Random Forest Classifier_min_weight_fraction_leaf : 0.0
# COMET INFO:     Random Forest Classifier_n_estimators             : 100
# COMET INFO:     Random Forest Classifier_n_jobs                   : -1
# COMET INFO:     Random Forest Classifier_oob_score                : False
# COMET INFO:     Random Forest Classifier_random_state             : 7650
# COMET INFO:     Random Forest Classifier_verbose                  : 0
# COMET INFO:     Random Forest Classifier_warm_start               : False
# COMET INFO:   Uploads:
# COMET INFO:     environment details : 1
# COMET INFO:     filename            : 1
# COMET INFO:     installed packages  : 1
# COMET INFO:     notebook            : 2
# COMET INFO:     os packages         : 1
# COMET INFO:     source_code         : 1
# COMET INFO:
# COMET WARNING: As you are running in a Jupyter environment, you will need to call `experiment.end()` when finished to ensure all metrics and code are logged before exiting.
# COMET ERROR: Failed to calculate active processors count. Fall back to default CPU count 1
# COMET INFO: Couldn't find a Git repository in '/content' nor in any parent directory. You can override where Comet is looking for a Git Patch by setting the configuration `COMET_GIT_DIRECTORY`
# COMET INFO: Experiment is live on comet.com https://www.comet.com/sherpan/pycaret-example/c28e1bf5098043ba9a2b2186cd42dd84
#
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO: Comet.ml Experiment Summary
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO:   Data:
# COMET INFO:     display_summary_level : 1
# COMET INFO:     url                   : https://www.comet.com/sherpan/pycaret-example/c28e1bf5098043ba9a2b2186cd42dd84
# COMET INFO:   Metrics:
# COMET INFO:     AUC      : 0.7912
# COMET INFO:     Accuracy : 0.7391
# COMET INFO:     F1       : 0.621
# COMET INFO:     Kappa    : 0.4228
# COMET INFO:     MCC      : 0.425
# COMET INFO:     Prec.    : 0.6278
# COMET INFO:     Recall   : 0.6199
# COMET INFO:     TT       : 0.179
# COMET INFO:   Others:
# COMET INFO:     Created from : pycaret
# COMET INFO:     Name         : Extreme Gradient Boosting
# COMET INFO:   Parameters:
# COMET INFO:     Extreme Gradient Boosting_base_score              : 1
# COMET INFO:     Extreme Gradient Boosting_booster                 : gbtree
# COMET INFO:     Extreme Gradient Boosting_callbacks               : 1
# COMET INFO:     Extreme Gradient Boosting_colsample_bylevel       : 1
# COMET INFO:     Extreme Gradient Boosting_colsample_bynode        : 1
# COMET INFO:     Extreme Gradient Boosting_colsample_bytree        : 1
# COMET INFO:     Extreme Gradient Boosting_early_stopping_rounds   : 1
# COMET INFO:     Extreme Gradient Boosting_enable_categorical      : False
# COMET INFO:     Extreme Gradient Boosting_eval_metric             : 1
# COMET INFO:     Extreme Gradient Boosting_feature_types           : 1
# COMET INFO:     Extreme Gradient Boosting_gamma                   : 1
# COMET INFO:     Extreme Gradient Boosting_gpu_id                  : 1
# COMET INFO:     Extreme Gradient Boosting_grow_policy             : 1
# COMET INFO:     Extreme Gradient Boosting_importance_type         : 1
# COMET INFO:     Extreme Gradient Boosting_interaction_constraints : 1
# COMET INFO:     Extreme Gradient Boosting_learning_rate           : 1
# COMET INFO:     Extreme Gradient Boosting_max_bin                 : 1
# COMET INFO:     Extreme Gradient Boosting_max_cat_threshold       : 1
# COMET INFO:     Extreme Gradient Boosting_max_cat_to_onehot       : 1
# COMET INFO:     Extreme Gradient Boosting_max_delta_step          : 1
# COMET INFO:     Extreme Gradient Boosting_max_depth               : 1
# COMET INFO:     Extreme Gradient Boosting_max_leaves              : 1
# COMET INFO:     Extreme Gradient Boosting_min_child_weight        : 1
# COMET INFO:     Extreme Gradient Boosting_missing                 : nan
# COMET INFO:     Extreme Gradient Boosting_monotone_constraints    : 1
# COMET INFO:     Extreme Gradient Boosting_n_estimators            : 100
# COMET INFO:     Extreme Gradient Boosting_n_jobs                  : -1
# COMET INFO:     Extreme Gradient Boosting_num_parallel_tree       : 1
# COMET INFO:     Extreme Gradient Boosting_objective               : binary:logistic
# COMET INFO:     Extreme Gradient Boosting_predictor               : 1
# COMET INFO:     Extreme Gradient Boosting_random_state            : 7650
# COMET INFO:     Extreme Gradient Boosting_reg_alpha               : 1
# COMET INFO:     Extreme Gradient Boosting_reg_lambda              : 1
# COMET INFO:     Extreme Gradient Boosting_sampling_method         : 1
# COMET INFO:     Extreme Gradient Boosting_scale_pos_weight        : 1
# COMET INFO:     Extreme Gradient Boosting_subsample               : 1
# COMET INFO:     Extreme Gradient Boosting_tree_method             : auto
# COMET INFO:     Extreme Gradient Boosting_use_label_encoder       : 1
# COMET INFO:     Extreme Gradient Boosting_validate_parameters     : 1
# COMET INFO:     Extreme Gradient Boosting_verbosity               : 0
# COMET INFO:   Uploads:
# COMET INFO:     environment details : 1
# COMET INFO:     filename            : 1
# COMET INFO:     installed packages  : 1
# COMET INFO:     notebook            : 2
# COMET INFO:     os packages         : 1
# COMET INFO:     source_code         : 1
# COMET INFO:
# COMET WARNING: As you are running in a Jupyter environment, you will need to call `experiment.end()` when finished to ensure all metrics and code are logged before exiting.
# COMET ERROR: Failed to calculate active processors count. Fall back to default CPU count 1
# COMET INFO: Couldn't find a Git repository in '/content' nor in any parent directory. You can override where Comet is looking for a Git Patch by setting the configuration `COMET_GIT_DIRECTORY`
# COMET INFO: Experiment is live on comet.com https://www.comet.com/sherpan/pycaret-example/8b3e852b83e94870910e3d469b1ba814
#
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO: Comet.ml Experiment Summary
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO:   Data:
# COMET INFO:     display_summary_level : 1
# COMET INFO:     url                   : https://www.comet.com/sherpan/pycaret-example/8b3e852b83e94870910e3d469b1ba814
# COMET INFO:   Metrics:
# COMET INFO:     AUC      : 0.7943
# COMET INFO:     Accuracy : 0.7318
# COMET INFO:     F1       : 0.5984
# COMET INFO:     Kappa    : 0.3986
# COMET INFO:     MCC      : 0.4022
# COMET INFO:     Prec.    : 0.6237
# COMET INFO:     Recall   : 0.583
# COMET INFO:     TT       : 0.136
# COMET INFO:   Others:
# COMET INFO:     Created from : pycaret
# COMET INFO:     Name         : Light Gradient Boosting Machine
# COMET INFO:   Parameters:
# COMET INFO:     Light Gradient Boosting Machine_boosting_type     : gbdt
# COMET INFO:     Light Gradient Boosting Machine_class_weight      : 1
# COMET INFO:     Light Gradient Boosting Machine_colsample_bytree  : 1.0
# COMET INFO:     Light Gradient Boosting Machine_importance_type   : split
# COMET INFO:     Light Gradient Boosting Machine_learning_rate     : 0.1
# COMET INFO:     Light Gradient Boosting Machine_max_depth         : -1
# COMET INFO:     Light Gradient Boosting Machine_min_child_samples : 20
# COMET INFO:     Light Gradient Boosting Machine_min_child_weight  : 0.001
# COMET INFO:     Light Gradient Boosting Machine_min_split_gain    : 0.0
# COMET INFO:     Light Gradient Boosting Machine_n_estimators      : 100
# COMET INFO:     Light Gradient Boosting Machine_n_jobs            : -1
# COMET INFO:     Light Gradient Boosting Machine_num_leaves        : 31
# COMET INFO:     Light Gradient Boosting Machine_objective         : 1
# COMET INFO:     Light Gradient Boosting Machine_random_state      : 7650
# COMET INFO:     Light Gradient Boosting Machine_reg_alpha         : 0.0
# COMET INFO:     Light Gradient Boosting Machine_reg_lambda        : 0.0
# COMET INFO:     Light Gradient Boosting Machine_silent            : warn
# COMET INFO:     Light Gradient Boosting Machine_subsample         : 1.0
# COMET INFO:     Light Gradient Boosting Machine_subsample_for_bin : 200000
# COMET INFO:     Light Gradient Boosting Machine_subsample_freq    : 0
# COMET INFO:   Uploads:
# COMET INFO:     environment details : 1
# COMET INFO:     filename            : 1
# COMET INFO:     installed packages  : 1
# COMET INFO:     notebook            : 2
# COMET INFO:     os packages         : 1
# COMET INFO:     source_code         : 1
# COMET INFO:
# COMET WARNING: As you are running in a Jupyter environment, you will need to call `experiment.end()` when finished to ensure all metrics and code are logged before exiting.
# COMET ERROR: Failed to calculate active processors count. Fall back to default CPU count 1
# COMET INFO: Couldn't find a Git repository in '/content' nor in any parent directory. You can override where Comet is looking for a Git Patch by setting the configuration `COMET_GIT_DIRECTORY`
# COMET INFO: Experiment is live on comet.com https://www.comet.com/sherpan/pycaret-example/449ffc25501d4d2abe15a087746039ab
#
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO: Comet.ml Experiment Summary
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO:   Data:
# COMET INFO:     display_summary_level : 1
# COMET INFO:     url                   : https://www.comet.com/sherpan/pycaret-example/449ffc25501d4d2abe15a087746039ab
# COMET INFO:   Metrics:
# COMET INFO:     AUC      : 0.7897
# COMET INFO:     Accuracy : 0.7206
# COMET INFO:     F1       : 0.5691
# COMET INFO:     Kappa    : 0.3652
# COMET INFO:     MCC      : 0.3696
# COMET INFO:     Prec.    : 0.6171
# COMET INFO:     Recall   : 0.5351
# COMET INFO:     TT       : 0.088
# COMET INFO:   Others:
# COMET INFO:     Created from : pycaret
# COMET INFO:     Name         : Naive Bayes
# COMET INFO:   Parameters:
# COMET INFO:     Naive Bayes_priors        : 1
# COMET INFO:     Naive Bayes_var_smoothing : 1e-09
# COMET INFO:   Uploads:
# COMET INFO:     environment details : 1
# COMET INFO:     filename            : 1
# COMET INFO:     installed packages  : 1
# COMET INFO:     notebook            : 2
# COMET INFO:     os packages         : 1
# COMET INFO:     source_code         : 1
# COMET INFO:
# COMET WARNING: As you are running in a Jupyter environment, you will need to call `experiment.end()` when finished to ensure all metrics and code are logged before exiting.
# COMET ERROR: Failed to calculate active processors count. Fall back to default CPU count 1
# COMET INFO: Couldn't find a Git repository in '/content' nor in any parent directory. You can override where Comet is looking for a Git Patch by setting the configuration `COMET_GIT_DIRECTORY`
# COMET INFO: Experiment is live on comet.com https://www.comet.com/sherpan/pycaret-example/f15fb0f6c70345b6ae9fb11db1a5ac84
#
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO: Comet.ml Experiment Summary
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO:   Data:
# COMET INFO:     display_summary_level : 1
# COMET INFO:     url                   : https://www.comet.com/sherpan/pycaret-example/f15fb0f6c70345b6ae9fb11db1a5ac84
# COMET INFO:   Metrics:
# COMET INFO:     AUC      : 0.7669
# COMET INFO:     Accuracy : 0.7151
# COMET INFO:     F1       : 0.544
# COMET INFO:     Kappa    : 0.3421
# COMET INFO:     MCC      : 0.3498
# COMET INFO:     Prec.    : 0.6196
# COMET INFO:     Recall   : 0.4927
# COMET INFO:     TT       : 0.268
# COMET INFO:   Others:
# COMET INFO:     Created from : pycaret
# COMET INFO:     Name         : Ada Boost Classifier
# COMET INFO:   Parameters:
# COMET INFO:     Ada Boost Classifier_algorithm      : SAMME.R
# COMET INFO:     Ada Boost Classifier_base_estimator : 1
# COMET INFO:     Ada Boost Classifier_learning_rate  : 1.0
# COMET INFO:     Ada Boost Classifier_n_estimators   : 50
# COMET INFO:     Ada Boost Classifier_random_state   : 7650
# COMET INFO:   Uploads:
# COMET INFO:     environment details : 1
# COMET INFO:     filename            : 1
# COMET INFO:     installed packages  : 1
# COMET INFO:     notebook            : 2
# COMET INFO:     os packages         : 1
# COMET INFO:     source_code         : 1
# COMET INFO:
# COMET WARNING: As you are running in a Jupyter environment, you will need to call `experiment.end()` when finished to ensure all metrics and code are logged before exiting.
# COMET ERROR: Failed to calculate active processors count. Fall back to default CPU count 1
# COMET INFO: Couldn't find a Git repository in '/content' nor in any parent directory. You can override where Comet is looking for a Git Patch by setting the configuration `COMET_GIT_DIRECTORY`
# COMET INFO: Experiment is live on comet.com https://www.comet.com/sherpan/pycaret-example/7e6ebd4de9bf4bbaac2188073808a608
#
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO: Comet.ml Experiment Summary
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO:   Data:
# COMET INFO:     display_summary_level : 1
# COMET INFO:     url                   : https://www.comet.com/sherpan/pycaret-example/7e6ebd4de9bf4bbaac2188073808a608
# COMET INFO:   Metrics:
# COMET INFO:     AUC      : 0.7913
# COMET INFO:     Accuracy : 0.7113
# COMET INFO:     F1       : 0.553
# COMET INFO:     Kappa    : 0.3423
# COMET INFO:     MCC      : 0.3471
# COMET INFO:     Prec.    : 0.607
# COMET INFO:     Recall   : 0.5129
# COMET INFO:     TT       : 0.085
# COMET INFO:   Others:
# COMET INFO:     Created from : pycaret
# COMET INFO:     Name         : Quadratic Discriminant Analysis
# COMET INFO:   Parameters:
# COMET INFO:     Quadratic Discriminant Analysis_priors           : 1
# COMET INFO:     Quadratic Discriminant Analysis_reg_param        : 0.0
# COMET INFO:     Quadratic Discriminant Analysis_store_covariance : False
# COMET INFO:     Quadratic Discriminant Analysis_tol              : 0.0001
# COMET INFO:   Uploads:
# COMET INFO:     environment details : 1
# COMET INFO:     filename            : 1
# COMET INFO:     installed packages  : 1
# COMET INFO:     notebook            : 2
# COMET INFO:     os packages         : 1
# COMET INFO:     source_code         : 1
# COMET INFO:
# COMET WARNING: As you are running in a Jupyter environment, you will need to call `experiment.end()` when finished to ensure all metrics and code are logged before exiting.
# COMET ERROR: Failed to calculate active processors count. Fall back to default CPU count 1
# COMET INFO: Couldn't find a Git repository in '/content' nor in any parent directory. You can override where Comet is looking for a Git Patch by setting the configuration `COMET_GIT_DIRECTORY`
# COMET INFO: Experiment is live on comet.com https://www.comet.com/sherpan/pycaret-example/5a20a660ef184faf9090f832088ac3e1
#
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO: Comet.ml Experiment Summary
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO:   Data:
# COMET INFO:     display_summary_level : 1
# COMET INFO:     url                   : https://www.comet.com/sherpan/pycaret-example/5a20a660ef184faf9090f832088ac3e1
# COMET INFO:   Metrics:
# COMET INFO:     AUC      : 0.7251
# COMET INFO:     Accuracy : 0.7037
# COMET INFO:     F1       : 0.5381
# COMET INFO:     Kappa    : 0.3229
# COMET INFO:     MCC      : 0.3269
# COMET INFO:     Prec.    : 0.5921
# COMET INFO:     Recall   : 0.4965
# COMET INFO:     TT       : 0.106
# COMET INFO:   Others:
# COMET INFO:     Created from : pycaret
# COMET INFO:     Name         : K Neighbors Classifier
# COMET INFO:   Parameters:
# COMET INFO:     K Neighbors Classifier_algorithm     : auto
# COMET INFO:     K Neighbors Classifier_leaf_size     : 30
# COMET INFO:     K Neighbors Classifier_metric        : minkowski
# COMET INFO:     K Neighbors Classifier_metric_params : 1
# COMET INFO:     K Neighbors Classifier_n_jobs        : -1
# COMET INFO:     K Neighbors Classifier_n_neighbors   : 5
# COMET INFO:     K Neighbors Classifier_p             : 2
# COMET INFO:     K Neighbors Classifier_weights       : uniform
# COMET INFO:   Uploads:
# COMET INFO:     environment details : 1
# COMET INFO:     filename            : 1
# COMET INFO:     installed packages  : 1
# COMET INFO:     notebook            : 2
# COMET INFO:     os packages         : 1
# COMET INFO:     source_code         : 1
# COMET INFO:
# COMET WARNING: As you are running in a Jupyter environment, you will need to call `experiment.end()` when finished to ensure all metrics and code are logged before exiting.
# COMET ERROR: Failed to calculate active processors count. Fall back to default CPU count 1
# COMET INFO: Couldn't find a Git repository in '/content' nor in any parent directory. You can override where Comet is looking for a Git Patch by setting the configuration `COMET_GIT_DIRECTORY`
# COMET INFO: Experiment is live on comet.com https://www.comet.com/sherpan/pycaret-example/2c9de99e97b84223ba21c1d9a3550ff9
#
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO: Comet.ml Experiment Summary
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO:   Data:
# COMET INFO:     display_summary_level : 1
# COMET INFO:     url                   : https://www.comet.com/sherpan/pycaret-example/2c9de99e97b84223ba21c1d9a3550ff9
# COMET INFO:   Metrics:
# COMET INFO:     AUC      : 0.6572
# COMET INFO:     Accuracy : 0.6835
# COMET INFO:     F1       : 0.5601
# COMET INFO:     Kappa    : 0.3151
# COMET INFO:     MCC      : 0.3195
# COMET INFO:     Prec.    : 0.5624
# COMET INFO:     Recall   : 0.5716
# COMET INFO:     TT       : 0.16
# COMET INFO:   Others:
# COMET INFO:     Created from : pycaret
# COMET INFO:     Name         : Decision Tree Classifier
# COMET INFO:   Parameters:
# COMET INFO:     Decision Tree Classifier_ccp_alpha                : 0.0
# COMET INFO:     Decision Tree Classifier_class_weight             : 1
# COMET INFO:     Decision Tree Classifier_criterion                : gini
# COMET INFO:     Decision Tree Classifier_max_depth                : 1
# COMET INFO:     Decision Tree Classifier_max_features             : 1
# COMET INFO:     Decision Tree Classifier_max_leaf_nodes           : 1
# COMET INFO:     Decision Tree Classifier_min_impurity_decrease    : 0.0
# COMET INFO:     Decision Tree Classifier_min_samples_leaf         : 1
# COMET INFO:     Decision Tree Classifier_min_samples_split        : 2
# COMET INFO:     Decision Tree Classifier_min_weight_fraction_leaf : 0.0
# COMET INFO:     Decision Tree Classifier_random_state             : 7650
# COMET INFO:     Decision Tree Classifier_splitter                 : best
# COMET INFO:   Uploads:
# COMET INFO:     environment details : 1
# COMET INFO:     filename            : 1
# COMET INFO:     installed packages  : 1
# COMET INFO:     notebook            : 2
# COMET INFO:     os packages         : 1
# COMET INFO:     source_code         : 1
# COMET INFO:
# COMET WARNING: As you are running in a Jupyter environment, you will need to call `experiment.end()` when finished to ensure all metrics and code are logged before exiting.
# COMET ERROR: Failed to calculate active processors count. Fall back to default CPU count 1
# COMET INFO: Couldn't find a Git repository in '/content' nor in any parent directory. You can override where Comet is looking for a Git Patch by setting the configuration `COMET_GIT_DIRECTORY`
# COMET INFO: Experiment is live on comet.com https://www.comet.com/sherpan/pycaret-example/b807ed6879e145cf92af974564d84e13
#
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO: Comet.ml Experiment Summary
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO:   Data:
# COMET INFO:     display_summary_level : 1
# COMET INFO:     url                   : https://www.comet.com/sherpan/pycaret-example/b807ed6879e145cf92af974564d84e13
# COMET INFO:   Metrics:
# COMET INFO:     AUC      : 0.5
# COMET INFO:     Accuracy : 0.6518
# COMET INFO:     F1       : 0.0
# COMET INFO:     Kappa    : 0.0
# COMET INFO:     MCC      : 0.0
# COMET INFO:     Prec.    : 0.0
# COMET INFO:     Recall   : 0.0
# COMET INFO:     TT       : 0.046
# COMET INFO:   Others:
# COMET INFO:     Created from : pycaret
# COMET INFO:     Name         : Dummy Classifier
# COMET INFO:   Parameters:
# COMET INFO:     Dummy Classifier_constant     : 1
# COMET INFO:     Dummy Classifier_random_state : 7650
# COMET INFO:     Dummy Classifier_strategy     : prior
# COMET INFO:   Uploads:
# COMET INFO:     environment details : 1
# COMET INFO:     filename            : 1
# COMET INFO:     installed packages  : 1
# COMET INFO:     notebook            : 2
# COMET INFO:     os packages         : 1
# COMET INFO:     source_code         : 1
# COMET INFO:
# COMET WARNING: As you are running in a Jupyter environment, you will need to call `experiment.end()` when finished to ensure all metrics and code are logged before exiting.
# COMET ERROR: Failed to calculate active processors count. Fall back to default CPU count 1
# COMET INFO: Couldn't find a Git repository in '/content' nor in any parent directory. You can override where Comet is looking for a Git Patch by setting the configuration `COMET_GIT_DIRECTORY`
# COMET INFO: Experiment is live on comet.com https://www.comet.com/sherpan/pycaret-example/1d1f0d106c994c158b7e39fb5c2e1aca

# %% [markdown]
# # Visualize Results

# %%
clf1[0].logging_param.loggers[0].finish_experiment()
clf1[0].logging_param.loggers[0].run.display('panels')
# Out:
#         <iframe
#             width="100%"
#             height="800px"
#             src="https://www.comet.com/sherpan/pycaret-example/1d1f0d106c994c158b7e39fb5c2e1aca"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
